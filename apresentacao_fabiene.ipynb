# %%
#!pip install matplotlib

# %%
from reportlab.lib.pagesizes import landscape, letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Image, Paragraph, Spacer, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.platypus import BaseDocTemplate, PageTemplate, Frame, NextPageTemplate

# %%
from reportlab.lib.pagesizes import landscape, letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Image, Paragraph, Spacer, PageBreak
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.platypus import BaseDocTemplate, PageTemplate, Frame, NextPageTemplate
import io

# Função para criar a apresentação em PDF
def criar_apresentacao_pdf():
    doc = BaseDocTemplate("apresentacao_fabiene.pdf", pagesize=landscape(letter))

    # Definir o cabeçalho (retângulo azul e logo da empresa)
    def header(canvas, doc):
        canvas.saveState()
        canvas.setFillColor(colors.blue)
        canvas.rect(0, doc.height - 17, doc.width + 150, doc.height, fill=True)
        canvas.restoreState()
        # Adicionar a imagem no canto esquerdo acima
        logo_empresa = "../logo.png"  # Substitua "renova.jpeg" pelo caminho da imagem do logo
        canvas.drawImage(logo_empresa, 3,  doc.height - 3, width=120, height=120)

    # Adicionar o cabeçalho na primeira página
    doc.addPageTemplates([PageTemplate(id='FirstPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])

    # Estilo do documento
    styles = getSampleStyleSheet()

    # Lista de elementos da apresentação
    Story = []

    # Adicionar o título
    titulo_style = ParagraphStyle('titulo_style', parent=styles['Title'], textColor=colors.white)
    titulo = Paragraph("                         Análises do 1º turno da eleição de 2020. Fonte: TSE", titulo_style)
    Story.append(titulo)
    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('tabelamaisvotados.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Criar um novo estilo 'NormalLarge' com tamanho de fonte 14.5 e espaçamento entre as linhas (leading) de 20
    styles.add(ParagraphStyle(name='NormalLarge', parent=styles['Normal'], fontSize=14.5, leading=20))

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto1 = Paragraph("No estado de São Paulo, os mais votados no primeiro turno da eleição de 2020 foram Bruno Covas e Guilherme Boulos com mais de um milhão de votos cada, conforme indicado.", styles['NormalLarge'])
    Story.append(texto1)


    # Avançar para a próxima página e adicionar o cabeçalho na segunda página
    doc.addPageTemplates([PageTemplate(id='SecondPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('SecondPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("       Maiores votos para os candidatos a prefeituras dos municípios de São Paulo", titulo_style_2)
    Story.append(titulo0)
    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('votoprefeito.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Os municípios com maiores votos para prefeitos no estado de São Paulo foram: Bruno Covas, com mais de um milhão de dados, Santo André, com Paulo Serra, com mais de 260 mil votos e São Bernardo do Campo, com Orlando Morando também com mais de 260mil votos.", styles['NormalLarge'])
    Story.append(texto2)
    


    # Avançar para a próxima página e adicionar o cabeçalho na segunda página
    doc.addPageTemplates([PageTemplate(id='ThirdPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('ThirdPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Análise dos maiores votos para Vereador nos municípios de São Paulo.", titulo_style_2)
    Story.append(titulo0)
    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('votovereador_partido.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Para Vereador, os maiores votos ocorreram novamente na Grande São Paulo, como em São Paulo, em Santo André e em São Bernardo do Campo, para o partido PSDB, e em Guarulhos para o PT.", styles['NormalLarge'])
    Story.append(texto2)

    


    # Avançar para a próxima página e adicionar o cabeçalho na segunda página
    doc.addPageTemplates([PageTemplate(id='FourthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('FourthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Análise dos maiores votos para Vereador nos municípios de São Paulo. ", titulo_style_2)
    Story.append(titulo0)
    titulo01 = Paragraph("Obs.:Apenas dos candidatos, sem levar em conta os votos dos partidos.", titulo_style_2)
    Story.append(titulo01)    
    Story.append(Spacer(15, 40))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('votovereador_candidatos.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Maior Voto dos candidatos para Vereadores em cada município, sem considerar o voto do partido, foi para o Suplicy, com mais de 160 mil votos, para a cidade de SP.", styles['NormalLarge'])
    Story.append(texto2)


    
    doc.addPageTemplates([PageTemplate(id='FifthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('FifthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Mapa dos condidatos mais votados à prefeitura de cada cidade do estado.", titulo_style_2)
    Story.append(titulo0)
    titulo01 = Paragraph("Maiores votos na cidade de SP.", titulo_style_2)
    Story.append(titulo01)
    Story.append(Spacer(15, 40))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('mapaprefeito.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Mapa indicando os maiores votos de um candidato em cada município do estado de São Paulo. Fonte: TSE. ", styles['NormalLarge'])
    Story.append(texto2)    
    
    
    doc.addPageTemplates([PageTemplate(id='SixthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('SixthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Mapa dos condidatos mais votados à vereador  ", titulo_style_2)
    Story.append(titulo0)
    titulo0 = Paragraph("em cada cidade do estado de São Paulo.", titulo_style_2)
    Story.append(titulo01)    
    Story.append(Spacer(15, 40))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('mapavereador.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Mapa indicando os maiores votos de um candidato em cada município do estado de São Paulo. Fonte: TSE.. ", styles['NormalLarge'])
    Story.append(texto2)    
        
#----------------------------------------------------Arquivo 2-------------------    
    doc.addPageTemplates([PageTemplate(id='SeventhPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('SeventhPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Perfil dos eleitores na cidade de São Paulo.", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo0)
    titulo01 = Paragraph("Com relação à idade", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo01)    
    Story.append(Spacer(15, 40))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('perfilidadeSP.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("As pessoas na faixa entre 60 e 69 anos foram as que mais votaram na eleição de 2020. ", styles['NormalLarge'])
    Story.append(texto2)  
    
    doc.addPageTemplates([PageTemplate(id='EighthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('EighthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Correlação do voto ao prefeito e perfil de idade ", titulo_style_2)
    titulo01 = Paragraph("Análise com base no Coeficiente de Pearson.", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo0)
    Story.append(titulo01)

    Story.append(Spacer(15, 40))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('correlacaoprefeito.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("A maior correlação em relação ao voto do Bruno Covas no primeiro turno: 1)Correlação de 0.47 na faixa de idade de: 80 a 84 anos; 2)e de 0.41 na faixa de idade de: 85 a 89 anos.. ", styles['NormalLarge'])
    Story.append(texto2)  
 

    doc.addPageTemplates([PageTemplate(id='NinthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('NinthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Análise pela escolaridade. ", titulo_style_2)
    #titulo01 = Paragraph("cancelaram abaixo de 1 ano de contrato", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo0)
   # Story.append(titulo01)

    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('prefeitocorrelacaoescola.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Conforme a última atualização do eleitorado, que teve maior correlação com o maior votação de Bruno Covas no primeiro turno:Correlação de 0.49 para o cadastrado no sistema do TSE com grau de escolaridade: ENSINO MÉDIO. ", styles['NormalLarge'])
    Story.append(texto2)  
    
#--------------------------------------------------------Arquivo 3---------------- 
    doc.addPageTemplates([PageTemplate(id='TenthPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('TenthPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Maiores votos para Vereador Suplicy", titulo_style_2)
    #titulo01 = Paragraph("cancelaram abaixo de 1 ano de contrato", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo0)
   # Story.append(titulo01)

    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
    figura = Image('vereadorvoto.png', width=600, height=280)
    Story.append(figura)
    Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("a faixa etária para quem votou em Eduardo Suplicy é maior. E uma delas é de 40 a 44 anos. Mais detalhes nos arquivos do programa em python. ", styles['NormalLarge'])
    Story.append(texto2)  
    
    doc.addPageTemplates([PageTemplate(id='EleventhPage', frames=[Frame(doc.leftMargin, doc.bottomMargin, doc.width, doc.height, id='normal')], onPage=header)])
    Story.append(NextPageTemplate('EleventhPage'))  # Avançar para a segunda página
    Story.append(PageBreak())  # Adicionar um quebra de página

    # Adicionar conteúdo à segunda página
    # Mudar o estilo do segundo título para 'titulo_style_2'
    # Utilizar o estilo 'titulo_style_2' para o segundo título
    titulo_style_2 = ParagraphStyle('titulo_style_2', parent=styles['Title'], textColor=colors.white, fontSize=14.5, leading=20)
    titulo0 = Paragraph("Finalizações", titulo_style_2)
    #titulo01 = Paragraph("cancelaram abaixo de 1 ano de contrato", titulo_style_2)
   # titulo0_width = titulo0.wrap(doc.width, doc.topMargin)[0]
   # canvas.drawString(doc.width - titulo0_width - 15, doc.height - 50, titulo0)  
    Story.append(titulo0)
   # Story.append(titulo01)

    Story.append(Spacer(15, 60))  # Espaço entre o título e o conteúdo da apresentação

    # Adicionar a figura de análise
  #  figura = Image('../pedidosmaiores.png', width=600, height=280)
  #  Story.append(figura)
 #   Story.append(Spacer(20, 25))  # Espaço entre a figura e o conteúdo da apresentação

    # Adicionar parágrafos de texto usando o estilo 'NormalLarge'
    texto2 = Paragraph("Os resultados se baseiam na correlação de Pearson, e usam como base a cidade de São Paulo, onde teve o maior eleitorado.\nMas, ressalta-se que esse metodo de calculo também poderá ser usado para os demais municípios do país. E servir como base para calculos e estudos mais profundos.", styles['NormalLarge'])
    Story.append(texto2)  
    Story.append(Spacer(20, 70))  # Espaço entre a figura e o conteúdo da apresentação
      
    textoeu="apresentação gerada em pdf usando a linguagem em python"
    texto2 = Paragraph( f'{textoeu}', styles['NormalLarge'])
    Story.append(texto2)    
    # Construir a apresentação
    doc.build(Story)

if __name__ == "__main__":
    criar_apresentacao_pdf()
